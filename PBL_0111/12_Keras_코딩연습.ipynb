# %% [markdown]
# # 12_Sequential Class 코딩 연습

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd

# %% [markdown]
# # 1.Linear Regression : 조금 어려운 데이터

# %% [markdown]
# ### 1.1 데이터 준비

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
boston

# %%
boston.feature_names

# %%
x = boston.data
y = boston.target

x.shape, y.shape

# %%
# 데이터 분할
from sklearn.model_selection import train_test_split
# 전체에서 train : test = 8 : 2
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
train_x.shape

# %%
train_x.shape[1]

# %% [markdown]
# **먼저 Network을 그려봅시다!!!**

# %% [markdown]
# ### 1.2 모델링

# %% [markdown]
# 모델은 model1 으로 생성하시오.

# %%
# 1. 모델 선언하기
# ①세션 비우기 : 기계적으로 수행하자.


# ② 모델 정의
model1 = 

# ③ 블록 준비


# ④ model에 블럭 추가하기


# ⑤ Compile

# %%
# 모델을 열어 봅시다.
model1.summary()

# %%
# 모델을 도식화 해 봅시다.
from keras.utils import plot_model
plot_model(model1)

# %%
# 2. 학습시키기
model1.    (     ,     , batch_size = 128, epochs = 10)

# %%
# 3. 예측하기
test_pred = model1.

# %%
# 4. 평가하기
from sklearn.metrics import mean_absolute_error, mean_squared_error
print(mean_absolute_error(test_y, test_pred))
print(mean_squared_error(test_y, test_pred, squared = False))

# %% [markdown]
# # 2.Logistic Regression : 조금 어려운 데이터

# %% [markdown]
# ### 2.1 데이터 준비

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
cancer.feature_names

# %%
x = cancer.data
y = cancer.target

# 모양 확인해봅시다.
x.shape, y.shape

# %%
# 데이터 분할
from sklearn.model_selection import train_test_split
# 전체에서 train : test = 8 : 2
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
train_x.shape

# %% [markdown]
# **먼제 Network를 그려봅시다!!!**

# %% [markdown]
# ### 2.2 모델링

# %% [markdown]
# 모델은 model2 으로 생성하시오.

# %%
# 1. 모델 선언하기
# ①세션 비우기 : 기계적으로 수행하자.


# ② 모델 정의
model2 = 

# ③ 블록 준비 


# ④ model에 블럭 추가하기


# ⑤ 컴파일

# %%
# 모델을 열어봅시다. .summary(), plot_model()

# %%
|# 2. 학습시키기(epochs, batch_size을 지정해 봅시다.)

# %%
# 3. 예측하기
test_pred =

# %%
# 4. 평가하기
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# 예측결과는 0~1 사이의 값으로 나오므로 0.1로 변환해줍니다.
test_pred2 = (test_pred >= 0.5).astype(int)

# %%
accuracy_score(test_y, test_pred2)

# %%
print(classification_report(test_y, test_pred2))

# %%
print(confusion_matrix(test_y, test_pred2))

# %% [markdown]
# #3.추가실습(옵션)

# %%
# model1,2 에 대해서 epochs를 늘려서 학습해 봅시다.
# 성능에 차이가 있나요?
