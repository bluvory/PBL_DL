# %% [markdown]
# # Flowers-17 : With Data Augmentation

# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
cd gdrive/My\ Drive/DL2
# Out:
# /content/gdrive/My Drive/DL2

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelBinarizer

from tensorflow. keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import cv2
import imutils
import os

# %% [markdown]
# Load images

# %%
imagePaths = list(paths.list_images("./datasets/flowers17/images"))
classNames = [pt.split(os.path.sep)[-2] for pt in imagePaths]
classNames = [str(x) for x in np.unique(classNames)]

# %%
len(classNames)
# Out:
# 17

# %% [markdown]
# Define preprocessor

# %%
def AspectAwarePreprocessor(image, width, height): 
    (h, w) = image.shape[:2]
    dW = 0
    dH = 0

    if w < h:
        image = imutils.resize(image, width=width)
        dH = int((image.shape[0] - height) / 2.0)

    else:
        image = imutils.resize(image, height=height)
        dW = int((image.shape[1] - width) / 2.0)

    (h, w) = image.shape[:2]
    image = image[dH:h - dH, dW:w - dW]


    return cv2.resize(image, (width, height))

# %% [markdown]
# Create images and labels dataset

# %%
# initialize the list of features and labels
data = []
labels = []
verbose = 500

# loop over the input images
for (i, imagePath) in enumerate(imagePaths):

    image = cv2.imread(imagePath)
    label = imagePath.split(os.path.sep)[-2]
    
    # Preprocessing using AspectAwarePreprocessor() 
    # instead of cv2.resize
    #
    #image = cv2.resize(image, 64, 64)
    image = AspectAwarePreprocessor(image, 64,64)


    data.append(image)
    labels.append(label)

    # show an update every `verbose` images
    if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
        print("[INFO] processed {}/{}".format(i + 1,
            len(imagePaths)))
        
data = np.array(data) 
labels = np.array(labels)

data = data.astype("float") / 255.0
# Out:
# [INFO] processed 500/1360
# [INFO] processed 1000/1360

# %% [markdown]
# Split Train/Test dataset

# %%
(trainX, testX, trainY, testY) = train_test_split(data, 
                                                  labels,
                                                  test_size=0.25, 
                                                  random_state=42)

# %% [markdown]
# Convert labels to one-hot encode

# %%
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# %% [markdown]
# Data augmentation
#
# * rotation : +/-30 degree
# * width shift : 10%
# * height shift : 10%
# * shear : 20%
# * zoom in/out : 20%
# * horizontal flip : True
# * fill mode : nearest

# %%
aug = ImageDataGenerator(rotation_range=30,
                         width_shift_range=0.1,
                         height_shift_range=0.1,
                         shear_range=0.2,
                         zoom_range=0.2,
                         fill_mode='nearest',
                         horizontal_flip=True

)

# %% [markdown]
# Define MiniVGGNet model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

class MiniVGGNet:
    @staticmethod
    def build(width, height, depth, classes):
        # initialize the model along with the input shape to be
        # "channels last" and the channels dimension itself
        model = Sequential()
        inputShape = (height, width, depth)
        chanDim = -1

        # first CONV => RELU => CONV => RELU => POOL layer set
        model.add(Conv2D(32, (3, 3), padding="same",
            input_shape=inputShape))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(32, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # second CONV => RELU => CONV => RELU => POOL layer set
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # first (and only) set of FC => RELU layers
        model.add(Flatten())
        model.add(Dense(512))
        model.add(Activation("relu"))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        # softmax classifier
        model.add(Dense(classes))
        model.add(Activation("softmax"))

        # return the constructed network architecture
        return model

# %% [markdown]
# Compiling model

# %%
opt = SGD(lr=0.05)
model = MiniVGGNet.build(width=64, height=64, depth=3,
                         classes=len(classNames))

model.compile(loss = "categorical_crossentropy", 
              optimizer = opt,
              metrics = ["accuracy"])

# %% [markdown]
# Training network

# %%
H = model.fit(aug.flow(trainX, trainY, batch_size=32),
              validation_data=(testX, testY),
              steps_per_epoch=len(trainX)//32,
              epochs=100, verbose=1
)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 2s 79ms/step - loss: 3.3154 - accuracy: 0.2156 - val_loss: 3.1691 - val_accuracy: 0.1441
# Epoch 2/100
# 31/31 [==============================] - 2s 59ms/step - loss: 2.4205 - accuracy: 0.3451 - val_loss: 2.6820 - val_accuracy: 0.2000
# Epoch 3/100
# 31/31 [==============================] - 2s 60ms/step - loss: 1.9717 - accuracy: 0.4241 - val_loss: 2.7504 - val_accuracy: 0.2176
# Epoch 4/100
# 31/31 [==============================] - 2s 61ms/step - loss: 1.7288 - accuracy: 0.4889 - val_loss: 2.7480 - val_accuracy: 0.2294
# Epoch 5/100
# 31/31 [==============================] - 2s 62ms/step - loss: 1.6702 - accuracy: 0.4889 - val_loss: 2.7065 - val_accuracy: 0.2912
# Epoch 6/100
# 31/31 [==============================] - 2s 63ms/step - loss: 1.6546 - accuracy: 0.4919 - val_loss: 2.8878 - val_accuracy: 0.2353
# Epoch 7/100
# 31/31 [==============================] - 2s 64ms/step - loss: 1.6500 - accuracy: 0.4848 - val_loss: 2.4697 - val_accuracy: 0.3059
# Epoch 8/100
# 31/31 [==============================] - 2s 63ms/step - loss: 1.3457 - accuracy: 0.5726 - val_loss: 2.3700 - val_accuracy: 0.3265
# Epoch 9/100
# 31/31 [==============================] - 2s 64ms/step - loss: 1.4535 - accuracy: 0.5567 - val_loss: 2.2241 - val_accuracy: 0.3471
# Epoch 10/100
# 31/31 [==============================] - 2s 64ms/step - loss: 1.3692 - accuracy: 0.5516 - val_loss: 2.3570 - val_accuracy: 0.3706
# Epoch 11/100
# 31/31 [==============================] - 2s 62ms/step - loss: 1.1913 - accuracy: 0.6083 - val_loss: 1.7826 - val_accuracy: 0.5029
# Epoch 12/100
# 31/31 [==============================] - 2s 62ms/step - loss: 1.2939 - accuracy: 0.5850 - val_loss: 1.6680 - val_accuracy: 0.5382
# Epoch 13/100
# 31/31 [==============================] - 2s 62ms/step - loss: 1.2730 - accuracy: 0.6012 - val_loss: 1.6810 - val_accuracy: 0.5382
# Epoch 14/100
# 31/31 [==============================] - 2s 62ms/step - loss: 1.0930 - accuracy: 0.6447 - val_loss: 1.4116 - val_accuracy: 0.5912
# Epoch 15/100
# 31/31 [==============================] - 2s 63ms/step - loss: 1.0811 - accuracy: 0.6306 - val_loss: 1.3407 - val_accuracy: 0.6176
# Epoch 16/100
# 31/31 [==============================] - 2s 63ms/step - loss: 1.1098 - accuracy: 0.6275 - val_loss: 1.3654 - val_accuracy: 0.5971
# Epoch 17/100
# 31/31 [==============================] - 2s 62ms/step - loss: 1.1715 - accuracy: 0.6083 - val_loss: 1.5276 - val_accuracy: 0.5882
# Epoch 18/100
# 31/31 [==============================] - 2s 63ms/step - loss: 1.0050 - accuracy: 0.6457 - val_loss: 1.4976 - val_accuracy: 0.6176
# Epoch 19/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.9772 - accuracy: 0.6731 - val_loss: 1.6040 - val_accuracy: 0.5824
# Epoch 20/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.9833 - accuracy: 0.6690 - val_loss: 1.4761 - val_accuracy: 0.5971
# Epoch 21/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.8790 - accuracy: 0.7045 - val_loss: 1.2633 - val_accuracy: 0.6353
# Epoch 22/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.9050 - accuracy: 0.6842 - val_loss: 1.4205 - val_accuracy: 0.6324
# Epoch 23/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.9054 - accuracy: 0.6804 - val_loss: 1.4956 - val_accuracy: 0.5971
# Epoch 24/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.9406 - accuracy: 0.6842 - val_loss: 1.4975 - val_accuracy: 0.6353
# Epoch 25/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.8629 - accuracy: 0.7186 - val_loss: 1.4403 - val_accuracy: 0.6118
# Epoch 26/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.8768 - accuracy: 0.7055 - val_loss: 1.5412 - val_accuracy: 0.6412
# Epoch 27/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.8846 - accuracy: 0.6964 - val_loss: 1.5275 - val_accuracy: 0.6059
# Epoch 28/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.8774 - accuracy: 0.6994 - val_loss: 1.5772 - val_accuracy: 0.6029
# Epoch 29/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.7983 - accuracy: 0.7298 - val_loss: 1.3041 - val_accuracy: 0.6353
# Epoch 30/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.7416 - accuracy: 0.7419 - val_loss: 1.3264 - val_accuracy: 0.6618
# Epoch 31/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.8040 - accuracy: 0.7237 - val_loss: 1.2014 - val_accuracy: 0.6971
# Epoch 32/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.7271 - accuracy: 0.7460 - val_loss: 1.2493 - val_accuracy: 0.6941
# Epoch 33/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.7057 - accuracy: 0.7632 - val_loss: 1.3397 - val_accuracy: 0.6588
# Epoch 34/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.7147 - accuracy: 0.7621 - val_loss: 1.3680 - val_accuracy: 0.6529
# Epoch 35/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.6515 - accuracy: 0.7824 - val_loss: 1.2811 - val_accuracy: 0.6500
# Epoch 36/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.6678 - accuracy: 0.7632 - val_loss: 1.3401 - val_accuracy: 0.6265
# Epoch 37/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.6797 - accuracy: 0.7662 - val_loss: 1.3339 - val_accuracy: 0.6265
# Epoch 38/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.6367 - accuracy: 0.7854 - val_loss: 1.3321 - val_accuracy: 0.6971
# Epoch 39/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.6658 - accuracy: 0.7672 - val_loss: 1.2892 - val_accuracy: 0.6382
# Epoch 40/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.6462 - accuracy: 0.7814 - val_loss: 1.2942 - val_accuracy: 0.6588
# Epoch 41/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.7430 - accuracy: 0.7682 - val_loss: 1.4291 - val_accuracy: 0.6647
# Epoch 42/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.7209 - accuracy: 0.7681 - val_loss: 1.1967 - val_accuracy: 0.7000
# Epoch 43/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.5623 - accuracy: 0.8087 - val_loss: 1.3045 - val_accuracy: 0.6853
# Epoch 44/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.6085 - accuracy: 0.7905 - val_loss: 1.7227 - val_accuracy: 0.5824
# Epoch 45/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.6607 - accuracy: 0.7814 - val_loss: 1.4217 - val_accuracy: 0.6471
# Epoch 46/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.6243 - accuracy: 0.7692 - val_loss: 1.2104 - val_accuracy: 0.7029
# Epoch 47/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.5397 - accuracy: 0.8097 - val_loss: 1.1528 - val_accuracy: 0.6882
# Epoch 48/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.5299 - accuracy: 0.8075 - val_loss: 1.2984 - val_accuracy: 0.7088
# Epoch 49/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.6073 - accuracy: 0.7966 - val_loss: 1.6686 - val_accuracy: 0.6118
# Epoch 50/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.5415 - accuracy: 0.8006 - val_loss: 1.2747 - val_accuracy: 0.6794
# Epoch 51/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.4725 - accuracy: 0.8300 - val_loss: 1.2590 - val_accuracy: 0.6941
# Epoch 52/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.5362 - accuracy: 0.8168 - val_loss: 1.2565 - val_accuracy: 0.6794
# Epoch 53/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.4795 - accuracy: 0.8279 - val_loss: 1.2485 - val_accuracy: 0.6794
# Epoch 54/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.4649 - accuracy: 0.8391 - val_loss: 1.3060 - val_accuracy: 0.7029
# Epoch 55/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.4856 - accuracy: 0.8289 - val_loss: 1.3380 - val_accuracy: 0.6765
# Epoch 56/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.4576 - accuracy: 0.8431 - val_loss: 1.3074 - val_accuracy: 0.6853
# Epoch 57/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.4950 - accuracy: 0.8492 - val_loss: 1.1907 - val_accuracy: 0.6971
# Epoch 58/100
# 31/31 [==============================] - 2s 65ms/step - loss: 0.4484 - accuracy: 0.8411 - val_loss: 1.3719 - val_accuracy: 0.6559
# Epoch 59/100
# 31/31 [==============================] - 2s 66ms/step - loss: 0.5218 - accuracy: 0.8209 - val_loss: 1.3502 - val_accuracy: 0.6882
# Epoch 60/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.4598 - accuracy: 0.8350 - val_loss: 3.1945 - val_accuracy: 0.4735
# Epoch 61/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.5701 - accuracy: 0.8097 - val_loss: 1.2398 - val_accuracy: 0.6941
# Epoch 62/100
# 31/31 [==============================] - 2s 65ms/step - loss: 0.4659 - accuracy: 0.8407 - val_loss: 1.2827 - val_accuracy: 0.6971
# Epoch 63/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.4445 - accuracy: 0.8492 - val_loss: 1.4170 - val_accuracy: 0.6912
# Epoch 64/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.4737 - accuracy: 0.8256 - val_loss: 1.1680 - val_accuracy: 0.7118
# Epoch 65/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.4593 - accuracy: 0.8512 - val_loss: 1.1475 - val_accuracy: 0.7235
# Epoch 66/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3921 - accuracy: 0.8573 - val_loss: 1.3761 - val_accuracy: 0.7088
# Epoch 67/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.4916 - accuracy: 0.8330 - val_loss: 1.2112 - val_accuracy: 0.6794
# Epoch 68/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.4019 - accuracy: 0.8593 - val_loss: 1.1572 - val_accuracy: 0.7147
# Epoch 69/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.3775 - accuracy: 0.8694 - val_loss: 1.2920 - val_accuracy: 0.7088
# Epoch 70/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3373 - accuracy: 0.8937 - val_loss: 1.1448 - val_accuracy: 0.7088
# Epoch 71/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3697 - accuracy: 0.8745 - val_loss: 1.2186 - val_accuracy: 0.6706
# Epoch 72/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.4249 - accuracy: 0.8522 - val_loss: 1.3406 - val_accuracy: 0.6853
# Epoch 73/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.3910 - accuracy: 0.8613 - val_loss: 1.6480 - val_accuracy: 0.6235
# Epoch 74/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.4151 - accuracy: 0.8573 - val_loss: 1.1743 - val_accuracy: 0.7059
# Epoch 75/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3946 - accuracy: 0.8715 - val_loss: 1.4104 - val_accuracy: 0.6824
# Epoch 76/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.3591 - accuracy: 0.8897 - val_loss: 1.1474 - val_accuracy: 0.7088
# Epoch 77/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3667 - accuracy: 0.8725 - val_loss: 1.2085 - val_accuracy: 0.6971
# Epoch 78/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.3544 - accuracy: 0.8644 - val_loss: 1.1669 - val_accuracy: 0.6971
# Epoch 79/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3786 - accuracy: 0.8684 - val_loss: 1.3123 - val_accuracy: 0.7029
# Epoch 80/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3383 - accuracy: 0.8755 - val_loss: 1.2618 - val_accuracy: 0.6912
# Epoch 81/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3730 - accuracy: 0.8725 - val_loss: 1.2775 - val_accuracy: 0.7000
# Epoch 82/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3113 - accuracy: 0.8877 - val_loss: 1.3188 - val_accuracy: 0.6912
# Epoch 83/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.2954 - accuracy: 0.8927 - val_loss: 1.6330 - val_accuracy: 0.6853
# Epoch 84/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.3539 - accuracy: 0.8846 - val_loss: 1.4995 - val_accuracy: 0.6706
# Epoch 85/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3123 - accuracy: 0.8897 - val_loss: 1.3736 - val_accuracy: 0.6853
# Epoch 86/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.3001 - accuracy: 0.8998 - val_loss: 1.2818 - val_accuracy: 0.7235
# Epoch 87/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.2892 - accuracy: 0.8968 - val_loss: 1.2449 - val_accuracy: 0.7147
# Epoch 88/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.2979 - accuracy: 0.8998 - val_loss: 1.2159 - val_accuracy: 0.7147
# Epoch 89/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.3455 - accuracy: 0.8816 - val_loss: 1.2725 - val_accuracy: 0.7324
# Epoch 90/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3098 - accuracy: 0.8937 - val_loss: 1.2627 - val_accuracy: 0.6971
# Epoch 91/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.2674 - accuracy: 0.9119 - val_loss: 1.2253 - val_accuracy: 0.7324
# Epoch 92/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3136 - accuracy: 0.8887 - val_loss: 1.5569 - val_accuracy: 0.6941
# Epoch 93/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3176 - accuracy: 0.8836 - val_loss: 1.3527 - val_accuracy: 0.7118
# Epoch 94/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3955 - accuracy: 0.8715 - val_loss: 1.4624 - val_accuracy: 0.7059
# Epoch 95/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.3567 - accuracy: 0.8775 - val_loss: 1.2936 - val_accuracy: 0.7265
# Epoch 96/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.3120 - accuracy: 0.8897 - val_loss: 1.2466 - val_accuracy: 0.7147
# Epoch 97/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.3253 - accuracy: 0.8907 - val_loss: 1.2100 - val_accuracy: 0.7206
# Epoch 98/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.3369 - accuracy: 0.8856 - val_loss: 1.3132 - val_accuracy: 0.7118
# Epoch 99/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.2927 - accuracy: 0.9079 - val_loss: 1.2662 - val_accuracy: 0.7088
# Epoch 100/100
# 31/31 [==============================] - 2s 64ms/step - loss: 0.2354 - accuracy: 0.9089 - val_loss: 1.2866 - val_accuracy: 0.7206

# %% [markdown]
# Evaluating network

# %%
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
                            predictions.argmax(axis=1), 
                            target_names=classNames))
# Out:
#               precision    recall  f1-score   support
#
#     bluebell       0.75      0.80      0.77        15
#    buttercup       0.67      0.84      0.74        19
#    coltsfoot       0.65      0.68      0.67        19
#      cowslip       0.74      0.67      0.70        21
#       crocus       0.40      0.80      0.53        20
#     daffodil       0.67      0.61      0.64        23
#        daisy       0.95      0.90      0.92        20
#    dandelion       0.79      0.75      0.77        20
#   fritillary       0.81      0.81      0.81        16
#         iris       1.00      0.63      0.77        27
#   lilyvalley       0.82      0.64      0.72        22
#        pansy       1.00      0.50      0.67        20
#     snowdrop       0.73      0.44      0.55        18
#    sunflower       1.00      1.00      1.00        16
#    tigerlily       0.92      0.96      0.94        23
#        tulip       0.37      0.39      0.38        18
#   windflower       0.62      0.87      0.73        23
#
#     accuracy                           0.72       340
#    macro avg       0.76      0.72      0.72       340
# weighted avg       0.76      0.72      0.72       340

# %% [markdown]
# Plot the training loss and accuracy

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 100), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 100), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 100), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
