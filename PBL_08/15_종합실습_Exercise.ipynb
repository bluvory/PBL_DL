# %% [markdown]
# # 15_종합실습

# %% [markdown]
# # 1. Linear Regression : bike_sharing

# %% [markdown]
# * 예제파일 01을 다시 열어서
# * 데이터를 가져와서 전처리(Dummy variable, Split, Scaling, DF to Numpy)수행
# * Functional API로 모델링

# %%
# 필요한 패키지 불러오기

# %%
# 데이터 불러와서 전처리하기

# %% [markdown]
# **Sequential Class**

# %% [markdown]
# **Functional API**

# %%
# 학습시키기

# %%
# 예측하기

# %%
# 평가하기

# %% [markdown]
# # 2. Logistic Regression : mobile

# %% [markdown]
# * 예제파일 02를 다시 열어서
# * 데이터를 가져와서 전처리(Dummy variable, Split, Scaling, DF to Numpy)수행
# * Functional API로 모델링

# %%
# 필요한 패키지 불러오기

# %%
# 데이터 불러와서 전처리하기



# target이 LEAVE, STAY로 되어 있습니다. 이를 1, 0으로 변환하시오.

# %% [markdown]
# **Sequential Class로 모델링**

# %%
# Sequential Class로 모델링

# %% [markdown]
# **Functional API로 모델링**

# %%
# Functional API로 모델링

# %%
# 학습시키기

# %%
# 예측하기

# %%
# 예측값은 0~1 사이 확률값으로 나옵니다.
# 0.5 기준으로 1과 0으로 변환하시오.

# %%
# 평가하기

# %% [markdown]
# # 3. 추가
# 모든 함수들을 모두 불러와서 모델링 해 봅시다.

# %%
# 여기에 불러오고...

# %%
# 아래 코드를 심플하게 수정

# 1. 모델 선언하기
# ①세션 비우기 : 기계적으로 수행하자.


# ② 모델 정의


# ③ 모델의 시작과 끝을 지정


# ④ 컴파일
